# %%
#데이터 로드 및 KOPIS일별 데이터 전처리
import os
from openpyxl import load_workbook
import pandas as pd

for (path, dir, files) in os.walk("F:\\drive\\WebWorkPlace2021\\jupyter\\code\\kopis_data\\KOPIS_STAT\\day_2019_2021"):
    print("path===================")
    print(path)
    print("dir=====================")
    print(dir)
    print("files=====================")
    print(files)
# Out:
# path===================
# F:\drive\WebWorkPlace2021\jupyter\code\kopis_data\KOPIS_STAT\day_2019_2021
# dir=====================
# ['201901', '201902', '201903', '201904', '201905', '201906', '201907', '201908', '201909', '201910', '201911', '201912', '202001', '202002', '202003', '202005', '202006', '202007', '202008', '202009', '202010', '202011', '202012', '202101', '202102', '202103', '202104', '202105', '202106', '202107', '202108', '202004']
# files=====================
# ['참고.txt']
# path===================
# F:\drive\WebWorkPlace2021\jupyter\code\kopis_data\KOPIS_STAT\day_2019_2021\201901
# dir=====================
# []
# files=====================
# ...

# %%
dirlist=[]
for (path, dir, files) in os.walk("F:\\drive\\WebWorkPlace2021\\jupyter\\code\\kopis_data\\KOPIS_STAT\\day_2019_2021"):
    print(dir)
    dirlist.append(dir)
# Out:
# ['201901', '201902', '201903', '201904', '201905', '201906', '201907', '201908', '201909', '201910', '201911', '201912', '202001', '202002', '202003', '202005', '202006', '202007', '202008', '202009', '202010', '202011', '202012', '202101', '202102', '202103', '202104', '202105', '202106', '202107', '202108', '202004']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []

# %%
filelist=[]
for (path, dir, files) in os.walk("F:\\drive\\WebWorkPlace2021\\jupyter\\code\\kopis_data\\KOPIS_STAT\\day_2019_2021\\201905"):
    print(files)
    filelist.append(files)
filelist[0]
# Out:
# ['종합통계 (31).xls', '종합통계 (01).xls', '종합통계 (02).xls', '종합통계 (03).xls', '종합통계 (04).xls', '종합통계 (05).xls', '종합통계 (06).xls', '종합통계 (07).xls', '종합통계 (08).xls', '종합통계 (09).xls', '종합통계 (10).xls', '종합통계 (11).xls', '종합통계 (12).xls', '종합통계 (13).xls', '종합통계 (14).xls', '종합통계 (15).xls', '종합통계 (16).xls', '종합통계 (17).xls', '종합통계 (18).xls', '종합통계 (19).xls', '종합통계 (20).xls', '종합통계 (21).xls', '종합통계 (22).xls', '종합통계 (23).xls', '종합통계 (24).xls', '종합통계 (25).xls', '종합통계 (26).xls', '종합통계 (27).xls', '종합통계 (28).xls', '종합통계 (29).xls', '종합통계 (30).xls']
# ['종합통계 (31).xls',
#  '종합통계 (01).xls',
#  '종합통계 (02).xls',
#  '종합통계 (03).xls',
#  '종합통계 (04).xls',
#  '종합통계 (05).xls',
#  '종합통계 (06).xls',
#  '종합통계 (07).xls',
#  '종합통계 (08).xls',
#  '종합통계 (09).xls',
#  '종합통계 (10).xls',
#  '종합통계 (11).xls',
#  '종합통계 (12).xls',
#  '종합통계 (13).xls',
#  '종합통계 (14).xls',
#  '종합통계 (15).xls',
#  '종합통계 (16).xls',
#  '종합통계 (17).xls',
#  '종합통계 (18).xls',
#  '종합통계 (19).xls',
#  '종합통계 (20).xls',
#  '종합통계 (21).xls',
#  '종합통계 (22).xls',
# ...

# %%
filelist[0].sort()

# %%
filelist[0]
# Out:
# ['종합통계 (01).xls',
#  '종합통계 (02).xls',
#  '종합통계 (03).xls',
#  '종합통계 (04).xls',
#  '종합통계 (05).xls',
#  '종합통계 (06).xls',
#  '종합통계 (07).xls',
#  '종합통계 (08).xls',
#  '종합통계 (09).xls',
#  '종합통계 (10).xls',
#  '종합통계 (11).xls',
#  '종합통계 (12).xls',
#  '종합통계 (13).xls',
#  '종합통계 (14).xls',
#  '종합통계 (15).xls',
#  '종합통계 (16).xls',
#  '종합통계 (17).xls',
#  '종합통계 (18).xls',
#  '종합통계 (19).xls',
#  '종합통계 (20).xls',
#  '종합통계 (21).xls',
#  '종합통계 (22).xls',
#  '종합통계 (23).xls',
#  '종합통계 (24).xls',
#  '종합통계 (25).xls',
#  '종합통계 (26).xls',
#  '종합통계 (27).xls',
#  '종합통계 (28).xls',
#  '종합통계 (29).xls',
#  '종합통계 (30).xls',
#  '종합통계 (31).xls']

# %%
dirlist_ = dirlist[0][4:-2]

# %%
len(dirlist_)
dirlist_[0]
# Out:
# '201905'

# %%
path="F:\\drive\\WebWorkPlace2021\\jupyter\\code\\kopis_data\\KOPIS_STAT\\day_2019_2021\\201901\\종합통계 (2).xls"
test = pd.read_excel(path)

# %%
play_cnt = []
open_cnt = []
run_cnt = []
price = []
reservation_cnt = []

# %%
for i in range(2,33):
    path=f"F:\\drive\\WebWorkPlace2021\\jupyter\\code\\kopis_data\\KOPIS_STAT\\day_2019_2021\\201901\\종합통계 ({i}).xls"
    file = pd.read_excel(path)
    play_cnt.append(file.iloc[62,:][2])
    open_cnt.append(file.iloc[62,:][4])
    run_cnt.append(file.iloc[62,:][6])
    price.append(file.iloc[62,:][8])
    reservation_cnt.append(file.iloc[62,:][10])
len(play_cnt)
# Out:
# 31

# %%
for i in range(33,61):
    path=f"F:\\drive\\WebWorkPlace2021\\jupyter\\code\\kopis_data\\KOPIS_STAT\\day_2019_2021\\201902\\종합통계 ({i}).xls"
    file = pd.read_excel(path)
    play_cnt.append(file.iloc[62,:][2])
    open_cnt.append(file.iloc[62,:][4])
    run_cnt.append(file.iloc[62,:][6])
    price.append(file.iloc[62,:][8])
    reservation_cnt.append(file.iloc[62,:][10])
len(play_cnt)
# Out:
# 59

# %%
for i in range(63,94):
    path=f"F:\\drive\\WebWorkPlace2021\\jupyter\\code\\kopis_data\\KOPIS_STAT\\day_2019_2021\\201903\\종합통계 ({i}).xls"
    file = pd.read_excel(path)
    play_cnt.append(file.iloc[62,:][2])
    open_cnt.append(file.iloc[62,:][4])
    run_cnt.append(file.iloc[62,:][6])
    price.append(file.iloc[62,:][8])
    reservation_cnt.append(file.iloc[62,:][10])
len(play_cnt)
# Out:
# 90

# %%
for i in range(94,123):
    path=f"F:\\drive\\WebWorkPlace2021\\jupyter\\code\\kopis_data\\KOPIS_STAT\\day_2019_2021\\201904\\종합통계 ({i}).xls"
    file = pd.read_excel(path)
    play_cnt.append(file.iloc[62,:][2])
    open_cnt.append(file.iloc[62,:][4])
    run_cnt.append(file.iloc[62,:][6])
    price.append(file.iloc[62,:][8])
    reservation_cnt.append(file.iloc[62,:][10])
len(play_cnt)
# Out:
# 119

# %%
dirlist_
# Out:
# ['201905',
#  '201906',
#  '201907',
#  '201908',
#  '201909',
#  '201910',
#  '201911',
#  '201912',
#  '202001',
#  '202002',
#  '202003',
#  '202004',
#  '202005',
#  '202006',
#  '202007',
#  '202008',
#  '202009',
#  '202010',
#  '202011',
#  '202012',
#  '202101',
#  '202102',
#  '202103',
#  '202104',
#  '202105',
#  '202106',
#  '202107']

# %%
temp = dirlist_[11:].copy()
dirlist_[11] = '202004'
dirlist_[12:]= temp
dirlist_
# Out:
# ['201905',
#  '201906',
#  '201907',
#  '201908',
#  '201909',
#  '201910',
#  '201911',
#  '201912',
#  '202001',
#  '202002',
#  '202003',
#  '202004',
#  '202005',
#  '202006',
#  '202007',
#  '202008',
#  '202009',
#  '202010',
#  '202011',
#  '202012',
#  '202101',
#  '202102',
#  '202103',
#  '202104',
#  '202105',
#  '202106',
#  '202107']

# %%
len(dirlist_)
# Out:
# 27

# %%
for i in range(27):
    dir_name = dirlist_[i]
    dir_path=f"F:\\drive\\WebWorkPlace2021\\jupyter\\code\\kopis_data\\KOPIS_STAT\\day_2019_2021\\{dir_name}"
    filelist=[]
    for (path, dir, files) in os.walk(dir_path):
        filelist.append(files)
        filelist[0].sort()
        for i in filelist[0]:
            print(i)
            file_path=f"{dir_path}\\{i}"
            file = pd.read_excel(file_path)
            play_cnt.append(file.iloc[62,:][2])
            open_cnt.append(file.iloc[62,:][4])
            run_cnt.append(file.iloc[62,:][6])
            price.append(file.iloc[62,:][8])
            reservation_cnt.append(file.iloc[62,:][10])
            len(play_cnt)
# Out:
# 종합통계 (01).xls
# 종합통계 (02).xls
# 종합통계 (03).xls
# 종합통계 (04).xls
# 종합통계 (05).xls
# 종합통계 (06).xls
# 종합통계 (07).xls
# 종합통계 (08).xls
# 종합통계 (09).xls
# 종합통계 (10).xls
# 종합통계 (11).xls
# 종합통계 (12).xls
# 종합통계 (13).xls
# 종합통계 (14).xls
# 종합통계 (15).xls
# 종합통계 (16).xls
# 종합통계 (17).xls
# 종합통계 (18).xls
# 종합통계 (19).xls
# 종합통계 (20).xls
# 종합통계 (21).xls
# 종합통계 (22).xls
# 종합통계 (23).xls
# 종합통계 (24).xls
# 종합통계 (25).xls
# 종합통계 (26).xls
# 종합통계 (27).xls
# 종합통계 (28).xls
# 종합통계 (29).xls
# 종합통계 (30).xls
# 종합통계 (31).xls
# 종합통계 (01).xls
# 종합통계 (02).xls
# 종합통계 (03).xls
# 종합통계 (04).xls
# 종합통계 (05).xls
# 종합통계 (06).xls
# 종합통계 (07).xls
# 종합통계 (08).xls
# 종합통계 (09).xls
# 종합통계 (10).xls
# 종합통계 (11).xls
# 종합통계 (12).xls
# 종합통계 (13).xls
# 종합통계 (14).xls
# 종합통계 (15).xls
# 종합통계 (16).xls
# 종합통계 (17).xls
# 종합통계 (18).xls
# 종합통계 (19).xls
# 종합통계 (20).xls
# 종합통계 (21).xls
# 종합통계 (22).xls
# 종합통계 (23).xls
# 종합통계 (24).xls
# 종합통계 (25).xls
# 종합통계 (26).xls
# 종합통계 (27).xls
# 종합통계 (28).xls
# 종합통계 (29).xls
# 종합통계 (30).xls
# 종합통계 (01).xls
# ...

# %%
print(len(play_cnt),
len(open_cnt),
len(run_cnt),
len(price),
len(reservation_cnt))
# Out:
# 942 942 942 942 942

# %%
play_cnt_sr = pd.Series(play_cnt)
open_cnt_sr = pd.Series(open_cnt)
run_cnt_sr = pd.Series(play_cnt)
price_sr = pd.Series(price)
reservation_cnt_sr = pd.Series(reservation_cnt)

# %%
columns = ['공연건수','개막편수','상연횟수','매출액','예매수']
dict_data = {'공연건수':play_cnt,
            '개막편수': open_cnt,
            '상연횟수': run_cnt,
            '매출액': price,
            '예매수': reservation_cnt}

# %%
df = pd.DataFrame(dict_data)

# %%
df.to_csv("201901_202107_종합통계.csv")

# %%
print(test.iloc[62,:][2])
print(test.iloc[62,:][4])
print(test.iloc[62,:][6])
print(test.iloc[62,:][8])
print(test.iloc[62,:][10])
# Out:
# 54
# 1
# 98
# 256853
# 7401

# %%
#여기까지 KOPIS 일별데이터 전처리

# %%
#txt형식으로 저장된 외부데이터에 대한 전처리
#기본적인 전처리 전 동일한 세팅을 해주는 함수 선언
import pandas as pd
def read_txt(file_name):
    txt = open(f'F:\\drive\\WebWorkPlace2021\\jupyter\\code\\kopis_data\\{file_name}',
              mode='r',encoding='utf-8')
    txt_ = txt.read()
    txt_ = txt_.split("\n")
    return txt_

# %%
ott_txt = open('F:\\drive\\WebWorkPlace2021\\jupyter\\code\\kopis_data\\OTT이용.txt',
               mode='r', encoding='utf-8')

# %%
ott = ott_txt.read()

# %%
ott = ott.split("\n")

# %%
ott[0].split(",")[1].split(":")[1]
# Out:
# ' 2278429'

# %%
len(ott[0].split(","))
# Out:
# 4

# %%
# def refiner(data_list):
#     data_list = data_list[:-1]
#     n_splits = len(data_list[0])
#     for index, j in enumerate(data_list):
#         block = j.split(",")
#         f

# %%
#OTT데이터 전처리
ott = ott[:-1]
ott_user_cnt = []
ott_user_install = []
ott_user_time = []
ott
for index, j in enumerate(ott):
    block = j.split(",")
    ott_user_cnt.append(block[1].split(":")[1])
    ott_user_install.append(block[2].split(":")[1])
    ott_user_time.append(block[3].split(":")[1][:-1])
print(ott_user_cnt)
print(ott_user_install)
print(ott_user_time)
# Out:
# [' 2278429', ' 2192766', ' 2113649', ' 2246025', ' 2506918', ' 2400953', ' 2169182', ' 2108250', ' 2166284', ' 2111353', ' 2269929', ' 2519460', ' 2557203', ' 2281348', ' 2104823', ' 2328069', ' 2195071', ' 2236620', ' 2542708', ' 2627791', ' 2189762', ' 2317288', ' 2156371', ' 2337394', ' 2519034', ' 2498102', ' 2516195', ' 2304901', ' 2275268', ' 2248390', ' 2460411', ' 2623376', ' 2879014', ' 2715617', ' 2401191', ' 2307948', ' 2417386', ' 2317329', ' 2290544', ' 2507969', ' 2798041', ' 2271212', ' 2131539', ' 2315943', ' 2521539', ' 2322919', ' 2451628', ' 2462901', ' 2171802', ' 2174567', ' 2240397', ' 2280876', ' 2352834', ' 2755835', ' 2667523', ' 2207377', ' 2088906', ' 2080944', ' 2420338', ' 2363788', ' 2626037', ' 2444202', ' 1917049', ' 1942545', ' 2114660', ' 2115476', ' 2058963', ' 2427058', ' 2561554', ' 2067157', ' 2080962', ' 2180678', ' 2200691', ' 2237228', ' 2473932', ' 2469875', ' 2049629', ' 1998551', ' 2003066', ' 2081282', ' 2295121', ' 2468436', ' 2435414', '
# ...

# %%
dict_data = {'ott이용자수':ott_user_cnt,
            'ott신규설치': ott_user_install,
            'ott사용시간': ott_user_time}

# %%
df = pd.DataFrame(dict_data)

# %%
df.to_csv("201901_202008_OTT이용.csv")

# %%
#배달앱 데이터 전처리
delivery=read_txt("배달앱이용.txt")

# %%
delivery = delivery[:-1]
del_user_cnt = []
del_user_install = []
del_user_time = []
ott
for index, j in enumerate(delivery):
    block = j.split(",")
    del_user_cnt.append(block[1].split(":")[1])
    del_user_install.append(block[2].split(":")[1])
    del_user_time.append(block[3].split(":")[1][:-1])
print(del_user_cnt)
print(del_user_install)
print(del_user_time)
# Out:
# [' 1817951', ' 1331170', ' 1337828', ' 1460992', ' 1774788', ' 1827031', ' 1434352', ' 1377954', ' 1413853', ' 1549309', ' 1567070', ' 1789552', ' 1922421', ' 1477875', ' 1440468', ' 1548692', ' 1426224', ' 1569356', ' 1776980', ' 1879549', ' 1432360', ' 1557066', ' 1382950', ' 1447951', ' 1680175', ' 1835099', ' 1890079', ' 1432439', ' 1418160', ' 1369512', ' 1544326', ' 1648946', ' 1772113', ' 1724263', ' 1400623', ' 1536614', ' 1883596', ' 1506062', ' 1571021', ' 1861959', ' 2035089', ' 1451893', ' 1477356', ' 1487766', ' 1523177', ' 2195156', ' 2185742', ' 2185617', ' 1671661', ' 1840837', ' 1720905', ' 1871603', ' 1849136', ' 2031061', ' 2161326', ' 1665417', ' 1659598', ' 1622318', ' 1865311', ' 1909881', ' 1917793', ' 1869131', ' 1355254', ' 1395093', ' 1350480', ' 1415586', ' 1529379', ' 1833275', ' 2077991', ' 1524225', ' 1567594', ' 1533433', ' 1544066', ' 1906891', ' 2014268', ' 2035689', ' 1524266', ' 1459660', ' 1649261', ' 1558167', ' 1734730', ' 2039030', ' 2072350', '
# ...

# %%
len(del_user_cnt)
# Out:
# 973

# %%
dict_data = {'배달앱이용자수':del_user_cnt,
            '배달앱신규설치': del_user_install,
            '배달앱사용시간': del_user_time}

# %%
df = pd.DataFrame(dict_data)
df.to_csv("201901_202008_배달앱이용.csv")

# %%
#화상회의앱 데이터 전처리
meeting = read_txt("화상회의앱.txt")
meeting = meeting[:-1]
user_cnt = []
user_install = []
user_time = []
ott
for index, j in enumerate(meeting):
    block = j.split(",")
    user_cnt.append(block[1].split(":")[1])
    user_install.append(block[2].split(":")[1])
    user_time.append(block[3].split(":")[1][:-1])
print(user_cnt)
print(user_install)
print(user_time)
dict_data = {'화상회의앱이용자수':user_cnt,
            '화상회의앱신규설치': user_install,
            '화상회의앱사용시간': user_time}
df = pd.DataFrame(dict_data)
df.to_csv("201901_202008_화상회의앱이용.csv")
# Out:
# [' 101655', ' 184982', ' 185860', ' 183741', ' 103989', ' 92403', ' 188285', ' 186733', ' 187250', ' 189837', ' 185733', ' 105412', ' 92937', ' 190228', ' 193375', ' 192129', ' 191783', ' 191331', ' 110305', ' 95791', ' 194815', ' 196654', ' 196216', ' 195363', ' 190193', ' 108506', ' 96031', ' 196415', ' 197233', ' 198985', ' 199276', ' 195947', ' 104408', ' 83140', ' 84824', ' 82081', ' 97675', ' 186977', ' 190679', ' 107301', ' 94449', ' 196543', ' 198408', ' 198591', ' 197365', ' 195198', ' 110709', ' 95665', ' 197124', ' 199288', ' 199179', ' 198877', ' 194805', ' 110681', ' 98674', ' 202579', ' 200492', ' 192011', ' 190683', ' 118349', ' 94743', ' 92723', ' 188588', ' 189024', ' 189216', ' 188998', ' 186277', ' 105070', ' 99576', ' 199502', ' 200240', ' 200349', ' 198369', ' 196774', ' 112019', ' 97511', ' 200008', ' 200720', ' 201033', ' 198524', ' 196754', ' 111465', ' 98177', ' 201627', ' 201943', ' 202436', ' 204031', ' 201923', ' 112427', ' 100429', ' 204975', ' 202355', '
# ...

# %%
#중고거래앱 데이터 전처리
used = read_txt("중고거래앱.txt")
used = used[:-1]
user_cnt = []
user_install = []
user_time = []
for index, j in enumerate(used):
    block = j.split(",")
    user_cnt.append(block[1].split(":")[1])
    user_install.append(block[2].split(":")[1])
    user_time.append(block[3].split(":")[1][:-1])
print(user_cnt)
print(user_install)
print(user_time)
dict_data = {'중고거래앱이용자수':user_cnt,
            '중고거래앱신규설치': user_install,
            '중고거래앱사용시간': user_time}
df = pd.DataFrame(dict_data)
df.to_csv("201901_202008_중고거래앱이용.csv")
# Out:
# [' 687089', ' 728950', ' 856760', ' 712943', ' 701326', ' 804023', ' 748717', ' 741526', ' 729448', ' 775663', ' 736601', ' 714922', ' 830979', ' 767020', ' 754942', ' 748840', ' 758561', ' 729398', ' 718025', ' 849016', ' 834852', ' 793033', ' 777882', ' 766762', ' 735865', ' 733410', ' 863688', ' 792746', ' 777085', ' 761297', ' 792057', ' 733492', ' 704092', ' 796650', ' 675564', ' 690642', ' 782658', ' 838796', ' 833054', ' 814969', ' 935038', ' 845765', ' 840490', ' 817540', ' 809955', ' 800692', ' 792320', ' 925059', ' 845859', ' 841674', ' 833976', ' 853830', ' 810728', ' 792786', ' 934586', ' 861801', ' 940195', ' 803793', ' 766869', ' 759242', ' 767903', ' 890653', ' 784006', ' 775360', ' 804578', ' 774909', ' 756569', ' 764725', ' 1030816', ' 855356', ' 857166', ' 857374', ' 830531', ' 804471', ' 809890', ' 951999', ' 861675', ' 850934', ' 864491', ' 841779', ' 821107', ' 821076', ' 1025644', ' 873720', ' 861680', ' 851071', ' 833305', ' 807153', ' 813612', ' 1032688', ' 86
# ...

# %%
#코로나 누락된 일별 데이터가 포함된 세 데이터 전처리
covid = read_txt("코로나.txt")

# %%
covid[0].split(",")[0].split(":")[2].split("T")[0].split("\"")[1]
# Out:
# '2020-01-20'

# %%
covid = read_txt("코로나.txt")
covid = covid[:-1]
date = []
user_cnt = []
for index, j in enumerate(covid):
    block = j.split(",")
    date.append(block[0].split(":")[2].split("T")[0].split("\"")[1])
    user_cnt.append(block[3].split(":")[1])
print(date)
print(user_cnt)
dict_data = {'날짜':date,'신규확진자수':user_cnt}
df = pd.DataFrame(dict_data)
df.to_csv("201901_202007_코로나확진자수.csv")
# Out:
# ['2020-01-20', '2020-01-21', '2020-01-22', '2020-01-23', '2020-01-24', '2020-01-25', '2020-01-26', '2020-01-27', '2020-01-28', '2020-01-29', '2020-01-30', '2020-01-31', '2020-02-01', '2020-02-02', '2020-02-03', '2020-02-04', '2020-02-05', '2020-02-06', '2020-02-07', '2020-02-08', '2020-02-09', '2020-02-10', '2020-02-11', '2020-02-12', '2020-02-13', '2020-02-14', '2020-02-15', '2020-02-16', '2020-02-17', '2020-02-18', '2020-02-19', '2020-02-20', '2020-02-21', '2020-02-22', '2020-02-23', '2020-02-24', '2020-02-25', '2020-02-26', '2020-02-27', '2020-02-28', '2020-02-29', '2020-03-01', '2020-03-02', '2020-03-03', '2020-03-04', '2020-03-05', '2020-03-06', '2020-03-07', '2020-03-08', '2020-03-09', '2020-03-10', '2020-03-11', '2020-03-12', '2020-03-13', '2020-03-14', '2020-03-15', '2020-03-16', '2020-03-17', '2020-03-18', '2020-03-19', '2020-03-20', '2020-03-21', '2020-03-22', '2020-03-23', '2020-03-24', '2020-03-25', '2020-03-26', '2020-03-27', '2020-03-28', '2020-03-29', '2020-03-30', '20
# ...

# %%
df.to_csv("201901_202007_코로나확진자수.csv")

# %%
df
# Out:
#              날짜 신규확진자수
# 0    2020-01-20      1
# 1    2020-01-21      0
# 2    2020-01-22      0
# 3    2020-01-23      0
# 4    2020-01-24      1
# ..          ...    ...
# 562  2021-08-07   1823
# 563  2021-08-06   1703
# 564  2021-08-05   1775
# 565  2021-08-04   1725
# 566  2021-08-03   1200
#
# [567 rows x 2 columns]

# %%
df = df.sort_values(by='날짜')['신규확진자수']

# %%
df
# Out:
# 0          1
# 1          0
# 2          0
# 3          0
# 4          1
#        ...
# 564     1775
# 563     1703
# 562     1823
# 561     1729
# 560     1492
# Name: 신규확진자수, Length: 567, dtype: object

# %%
#서울 지하철 이용 데이터 전처리(모델에는 이 데이터가 쓰이지는 않음)
subway = read_txt("서울지하철이용.txt")

user_cnt = []
time = []
for index, j in enumerate(subway):
    user_cnt.append(j.split(",")[1].split("{")[1][:-2].split(":")[1][1:])
    temp = j.split(",")[0].split("{")[1][:-2].split(":")[1][1:].split("\"")[1].\
    split("T")[0]
    time.append(temp)
print(time)
dict_data = {'지하철이용자수':user_cnt}
df = pd.DataFrame(dict_data)
df.to_csv("201901_202007_지하철이용자수.csv")
# dict_data = {'날짜': time,
#             '확인':time}
# df = pd.DataFrame(dict_data)
# Out:
# ['2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04', '2019-01-05', '2019-01-06', '2019-01-07', '2019-01-08', '2019-01-09', '2019-01-10', '2019-01-11', '2019-01-12', '2019-01-13', '2019-01-14', '2019-01-15', '2019-01-16', '2019-01-17', '2019-01-18', '2019-01-19', '2019-01-20', '2019-01-21', '2019-01-22', '2019-01-23', '2019-01-24', '2019-01-25', '2019-01-26', '2019-01-27', '2019-01-28', '2019-01-29', '2019-01-30', '2019-01-31', '2019-02-01', '2019-02-02', '2019-02-03', '2019-02-04', '2019-02-05', '2019-02-06', '2019-02-07', '2019-02-08', '2019-02-09', '2019-02-10', '2019-02-11', '2019-02-12', '2019-02-13', '2019-02-14', '2019-02-15', '2019-02-16', '2019-02-17', '2019-02-18', '2019-02-19', '2019-02-20', '2019-02-21', '2019-02-22', '2019-02-23', '2019-02-24', '2019-02-25', '2019-02-26', '2019-02-27', '2019-02-28', '2019-03-01', '2019-03-02', '2019-03-03', '2019-03-04', '2019-03-05', '2019-03-06', '2019-03-07', '2019-03-08', '2019-03-09', '2019-03-10', '2019-03-11', '2019-03-12', '20
# ...

# %%
df_date = pd.read_csv(
    'F:\\drive\\WebWorkPlace2021\\jupyter\\code\\kopis_data\\날짜.csv'
                             ,encoding='cp949')
temp = pd.merge(left = df , right = df_date, how = "outer", on = "날짜")
temp = temp.sort_values(by='날짜')
temp.to_csv('F:\\drive\\WebWorkPlace2021\\jupyter\\code\\kopis_data\\누락날짜확인.csv')

# %%
subway = read_txt("서울지하철이용.txt")

# %%
subway
# Out:
# ['365: {date: "2019-01-01T00:00:00.000Z", sum: {total: 2169874}}',
#  '366: {date: "2019-01-02T00:00:00.000Z", sum: {total: 5067609}}',
#  '367: {date: "2019-01-03T00:00:00.000Z", sum: {total: 5255830}}',
#  '368: {date: "2019-01-04T00:00:00.000Z", sum: {total: 5485567}}',
#  '369: {date: "2019-01-05T00:00:00.000Z", sum: {total: 3921397}}',
#  '370: {date: "2019-01-06T00:00:00.000Z", sum: {total: 2777687}}',
#  '371: {date: "2019-01-07T00:00:00.000Z", sum: {total: 5199344}}',
#  '372: {date: "2019-01-08T00:00:00.000Z", sum: {total: 5278474}}',
#  '373: {date: "2019-01-09T00:00:00.000Z", sum: {total: 5209324}}',
#  '374: {date: "2019-01-10T00:00:00.000Z", sum: {total: 5313334}}',
#  '375: {date: "2019-01-11T00:00:00.000Z", sum: {total: 5526570}}',
#  '376: {date: "2019-01-12T00:00:00.000Z", sum: {total: 4065243}}',
#  '377: {date: "2019-01-13T00:00:00.000Z", sum: {total: 2834657}}',
#  '378: {date: "2019-01-14T00:00:00.000Z", sum: {total: 5105177}}',
# ...

# %%
#지하철 직접 집계
subway_raw = pd.read_csv("지하철_202108.csv", encoding="cp949")

# %%
subway_agg = subway_raw.groupby("사용일자").sum()

# %%
subway_agg = subway_agg.sort_values(by='사용일자')

# %%
subway_agg.to_csv("지하철202107_202108.csv")

# %%
movie = read_txt("영화(201801_202106).txt")

# %%
#영화관람 데이터 전처리(모델에는 안쓰임)
movie_list = []
for i in movie:
    temp = i.split(",")[3].split(":")[1][1:]
    movie_list.append(temp)
movie_list
dict_data = {"movie_sales":movie_list}
movie_df = pd.DataFrame(dict_data)
movie_df
# Out:
#      movie_sales
# 0    10309962150
# 1     2805968850
# 2     3086189000
# 3     3357281295
# 4     7145939653
# ..           ...
# 907   3338439630
# 908   2990616610
# 909    999626730
# 910    996710000
# 911   1243958090
#
# [912 rows x 1 columns]

# %%
movie_df.to_csv("201901_202106_영화매출액.csv")

# %%
import pandas as pd

# %%
# art = read_txt("공연202107.txt")
# art
# art = read_txt("공연202108.txt")
# art
# Out:
# ['1308: {date: "2021-08-01T00:00:00.000Z", show: 172, open: 23, release: 271, sales: 1438176, reserv: 27846}',
#  '1309: {date: "2021-08-02T00:00:00.000Z", show: 30, open: 6, release: 44, sales: 44591, reserv: 4537}',
#  '1310: {date: "2021-08-03T00:00:00.000Z", show: 81, open: 18, release: 110, sales: 421477, reserv: 10558}',
#  '1311: {date: "2021-08-04T00:00:00.000Z", show: 98, open: 18, release: 150, sales: 634912, reserv: 15742}',
#  '1312: {date: "2021-08-05T00:00:00.000Z", show: 115, open: 27, release: 157, sales: 456589, reserv: 13922}',
#  '1313: {date: "2021-08-06T00:00:00.000Z", show: 133, open: 24, release: 188, sales: 654308, reserv: 16121}',
#  '1314: {date: "2021-08-07T00:00:00.000Z", show: 190, open: 42, release: 332, sales: 1574779, reserv: 31914}',
#  '1315: {date: "2021-08-08T00:00:00.000Z", show: 152, open: 12, release: 257, sales: 1362942, reserv: 25861}',
#  '1316: {date: "2021-08-09T00:00:00.000Z", show: 29, open: 4, release: 36, sales: 13171, reserv: 3812}',
# ...

# %%
# l=[]
# for i in art:
#     l.append(i.split(":")[-1].split("}")[0][1:])
# dict_data={'예매수':l}
# df = pd.DataFrame(dict_data)
# df.to_csv("202108공연예매수.csv")

# %%
#월별데이터도 같은 방법으로 전처리

# %%
df = pd.read_csv("F:\\drive\\WebWorkPlace2021\\jupyter\\code\\201801_202106_공연예매수.csv")
df
# Out:
#             date  ticketing_count
# 0     2018/01/01             4408
# 1     2018/01/02             3144
# 2     2018/01/03             7729
# 3     2018/01/04             4738
# 4     2018/01/05             6296
# ...          ...              ...
# 1272  2021/06/26            51912
# 1273  2021/06/27            37135
# 1274  2021/06/28             3911
# 1275  2021/06/29            10714
# 1276  2021/06/30            19878
#
# [1277 rows x 2 columns]

# %%
# df['date']=df['date'].str.split("/").str[0]+"/"+df['date'].str.split("/").str[1]

# %%
# df = df.groupby('date').sum()

# %%
# df.to_csv("201801_202106_월별공연예매수.csv")

# %%
df = pd.read_csv("F:\\download\\CARD_SUBWAY_MONTH_201901.csv",encoding='cp949')

# %%
#모델에 쓰인 지하철 데이터 전처리
import pandas as pd

# %%
subway_list = []
for i in range(1,10):
    subway_list.append(pd.read_csv(f"F:\\download\\CARD_SUBWAY_MONTH_20190{i}.csv",encoding='cp949'))
df_10=pd.read_csv(f"F:\\download\\CARD_SUBWAY_MONTH_201910.csv",encoding='cp949')
df_11=pd.read_csv(f"F:\\download\\CARD_SUBWAY_MONTH_201911.csv",encoding='cp949')
df_12=pd.read_csv(f"F:\\download\\CARD_SUBWAY_MONTH_201912.csv",encoding='cp949')
subway_list.append(df_10)
subway_list.append(df_11)
subway_list.append(df_12)

# %%
subway_list
# Out:
# [           사용일자    노선명          역명   승차총승객수   하차총승객수      등록일자
#  0      20190101    2호선       을지로4가   3862.0   3728.0  20190104
#  1      20190101    2호선       을지로3가   8104.0   7554.0  20190104
#  2      20190101    2호선       을지로입구  22478.0  21330.0  20190104
#  3      20190101    2호선          시청   8381.0   6049.0  20190104
#  4      20190101    1호선         동묘앞   8045.0   8504.0  20190104
#  ...         ...    ...         ...      ...      ...       ...
#  18329  20190131  우이신설선      북한산보국문   6195.0   5786.0  20190203
#  18330  20190131  우이신설선          정릉   4600.0   4211.0  20190203
#  18331  20190131  우이신설선  성신여대입구(돈암)   3922.0   4289.0  20190203
#  18332  20190131  우이신설선          보문   1659.0   1693.0  20190203
#  18333  20190131  우이신설선         신설동   2075.0   2215.0  20190203
#
#  [18334 rows x 6 columns],
#             사용일자  노선명         역명   승차총승객수   하차총승객수      등록일자
#  0      20190201  6호선        이태원  15786.0  21324.0  20190204
# ...

# %%
#df_8은 나누기 2
subway_list.append(df)

# %%
df1=pd.read_csv(f"F:\\download\\CARD_SUBWAY_MONTH_202001.csv",encoding='cp949')
df2=pd.read_csv(f"F:\\download\\CARD_SUBWAY_MONTH_202002.csv",encoding='cp949')
df3=pd.read_csv(f"F:\\download\\CARD_SUBWAY_MONTH_202003.csv",encoding='cp949')
df4=pd.read_csv(f"F:\\download\\CARD_SUBWAY_MONTH_202004.csv",encoding='cp949')
subway_list.append(df1)
subway_list.append(df2)
subway_list.append(df3)
subway_list.append(df4)

# %%
df1=pd.read_csv(f"F:\\download\\CARD_SUBWAY_MONTH_202005.csv",encoding='cp949')
df2=pd.read_csv(f"F:\\download\\CARD_SUBWAY_MONTH_202006.csv",encoding='cp949')
df3=pd.read_csv(f"F:\\download\\CARD_SUBWAY_MONTH_202007.csv",encoding='cp949')
df4=pd.read_csv(f"F:\\download\\CARD_SUBWAY_MONTH_202008.csv",encoding='cp949')
subway_list.append(df1)
subway_list.append(df2)
subway_list.append(df3)
subway_list.append(df4)

# %%
df1=pd.read_csv(f"F:\\download\\CARD_SUBWAY_MONTH_202009.csv",encoding='cp949')
df2=pd.read_csv(f"F:\\download\\CARD_SUBWAY_MONTH_202010.csv",encoding='cp949')
df3=pd.read_csv(f"F:\\download\\CARD_SUBWAY_MONTH_202011.csv",encoding='cp949')
df4=pd.read_csv(f"F:\\download\\CARD_SUBWAY_MONTH_202012.csv",encoding='cp949')
subway_list.append(df1)
subway_list.append(df2)
subway_list.append(df3)
subway_list.append(df4)

# %%
len(subway_list)
# Out:
# 31

# %%
for i in range(1,8):
    subway_list.append(pd.read_csv(f"F:\\download\\CARD_SUBWAY_MONTH_20210{i}.csv",encoding='cp949'))

# %%
subway_list_2 = []
for i in subway_list:
    subway_list_2.append(i.loc[:,['사용일자','승차총승객수']])

# %%
len(subway_list_2)
# Out:
# 31

# %%
res=pd.DataFrame()
for i in subway_list_2:
    print(i.groupby("사용일자").sum())
    res = pd.concat([res,i.groupby("사용일자").sum()])
# Out:
#              승차총승객수
# 사용일자
# 20190101  3419948.0
# 20190102  7621668.0
# 20190103  7873692.0
# 20190104  8270345.0
# 20190105  6062294.0
# 20190106  4408718.0
# 20190107  7824428.0
# 20190108  7913162.0
# 20190109  7815405.0
# 20190110  7977300.0
# 20190111  8351322.0
# 20190112  6282189.0
# 20190113  4501053.0
# 20190114  7680436.0
# 20190115  7826713.0
# 20190116  7891108.0
# 20190117  8034764.0
# 20190118  8361638.0
# 20190119  6259796.0
# 20190120  4530960.0
# 20190121  7736189.0
# 20190122  7929541.0
# 20190123  8034871.0
# 20190124  8082710.0
# 20190125  8438603.0
# 20190126  6350557.0
# 20190127  4635486.0
# 20190128  7845049.0
# 20190129  7948890.0
# 20190130  8039829.0
# 20190131  7899350.0
#              승차총승객수
# 사용일자
# 20190201  7979109.0
# 20190202  5079486.0
# 20190203  3412440.0
# 20190204  2941955.0
# 20190205  2837335.0
# 20190206  3741895.0
# 20190207  7401179.0
# 20190208  7913111.0
# 20190209  6002458.0
# 20190210  4360767.0
# 20190211  7942263.0
# ...

# %%
res.to_csv("지하철201901_202107.csv")
